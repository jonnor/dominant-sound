# %%
import os
import pandas
from src.utils.fileutils import get_project_root

# %%
root_path = get_project_root()
data_path = os.path.join(root_path, 'data/processed')

# %%
# Scores and ebdeddings for EfficientAT have been saved in "data/processed/"
scores_dir = os.path.join(data_path, 'scores_EAT')
emb_dir = os.path.join(data_path, 'embeddings_EAT')

# %%
test_file = 'maestro_cafe_restaurant_08.parquet'

# %%
scores = pandas.read_parquet(os.path.join(scores_dir, test_file))
embeddings = pandas.read_parquet(os.path.join(emb_dir, test_file))

# %%
scores
# Out:
#            c0        c1        c2        c3        c4        c5        c6  \
# 0    0.010027  0.001537  0.002917  0.000534  0.000794  0.004655  0.001388
# 1    0.270303  0.011566  0.007255  0.000583  0.005850  0.022380  0.000200
# 2    0.480980  0.005884  0.009646  0.001276  0.002156  0.006934  0.000109
# 3    0.073638  0.002784  0.003723  0.000873  0.001759  0.003906  0.000519
# 4    0.014828  0.001413  0.002155  0.000769  0.000889  0.002723  0.000637
# ..        ...       ...       ...       ...       ...       ...       ...
# 239  0.518527  0.008335  0.015009  0.001263  0.006457  0.015481  0.000212
# 240  0.072910  0.001245  0.003076  0.000228  0.000511  0.003498  0.000165
# 241  0.022702  0.001200  0.001177  0.000411  0.000497  0.002016  0.000093
# 242  0.012099  0.000953  0.002027  0.000595  0.000369  0.001937  0.000241
# 243  0.001608  0.000365  0.000512  0.006031  0.000079  0.000740  0.487329
#
#            c7        c8        c9  ...          c518      c519      c520  \
# ...

# %%
embeddings
# Out:
#            e0        e1        e2        e3        e4        e5        e6  \
# 0    0.248894 -0.169377  0.004738  0.493493  0.033850 -0.266867 -0.304145
# 1    0.220791 -0.265375 -0.057179  0.591674  0.024406 -0.160344 -0.285507
# 2    0.134848 -0.216336 -0.091356  0.341639  0.065125 -0.263627 -0.264828
# 3    0.173841 -0.147514 -0.064443  1.012411  0.008384 -0.176212 -0.188365
# 4    0.142196 -0.275452 -0.047757  0.423324  0.084834 -0.210957 -0.249951
# ..        ...       ...       ...       ...       ...       ...       ...
# 239  0.384722 -0.193745  0.013148  0.496767 -0.018247 -0.181235 -0.221279
# 240  0.142224 -0.124464 -0.049359  0.433831 -0.137505 -0.138310 -0.267816
# 241 -0.070486 -0.270684 -0.043208  0.477113  0.234991 -0.223022 -0.174667
# 242  0.175475 -0.138858  0.091347  0.347037  0.016251 -0.181873 -0.306540
# 243  0.344527 -0.050578 -0.088403  0.028422  0.069313 -0.162364 -0.079221
#
#            e7        e8        e9  ...      e951      e952      e953  \
# ...
